# %% [markdown]
# Article for inspiration: https://www.snowflake.com/blog/container-services-llama2-snowpark-ml/
#
# Compute Pool: skhara_compute_gpu7

# %%
# !pip install transformers

# %%
from snowflake.snowpark.session import Session
from snowflake.ml.registry import model_registry
from snowflake.ml.model import deploy_platforms

import json
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
connection_parameters = json.load(open('creds.json'))
session = Session.builder.configs(connection_parameters).create()

# %% [markdown]
# # LLAMA Model Setup

# %% [markdown]
# ## Load LLAMA Model

# %%
HF_AUTH_TOKEN = "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" #Your token from Hugging Face

# %%
from transformers import pipeline
from snowflake.ml.model.models import huggingface_pipeline

llama_model = huggingface_pipeline.HuggingFacePipelineModel(task="text-generation",
                                                            model="meta-llama/Llama-2-7b-chat-hf",
                                                            token=HF_AUTH_TOKEN,
                                                            return_full_text=False,
                                                            max_new_tokens=100)

# %% [markdown]
# ## Register the model

# %%
registry_name = 'SKHARA'
schema_name = 'BUILD_REGISTRY'

model_registry.create_model_registry(session= session,
                                     database_name= registry_name,
                                     schema_name= schema_name)

registry = model_registry.ModelRegistry(session= session,
                                        database_name= registry_name,
                                        schema_name= schema_name)
# Out:
# create_model_registry() is in private preview since 0.2.0. Do not use it in production.
# WARNING:absl:The database SKHARA already exists. Skipping creation.
# WARNING:absl:The schema SKHARA.BUILD_REGISTRY already exists. Skipping creation.

# %%
MODEL_NAME = "LLAMA2_MODEL_7b_CHAT"
MODEL_VERSION = "7"

llama_model_ref= registry.log_model(
    model_name=MODEL_NAME,
    model_version=MODEL_VERSION,
    model=llama_model
)

llama_model_ref

# %% [markdown]
# ## Deploy Model

# %%
llama_model_ref.deploy(
    deployment_name="llama_predict",
    platform= deploy_platforms.TargetPlatform.SNOWPARK_CONTAINER_SERVICES,
    options={"compute_pool": "SKHARA_COMPUTE_GPU3",
             "num_gpus": 1,
             # Remove the 'prebuilt_snowflake_image' argument below when running .deploy() for the first time
             #"prebuilt_snowflake_image": "sfsenorthamerica-fcto-spc.registry.snowflakecomputing.com/skhara/build_registry/snowml_repo/116da812e88f2751324c6a16eb00de3726ed06a3:latest"
            },
    permanent = True,
)
# Out:
# WARNING:snowflake.ml.model._deploy_client.snowservice.deploy:Similar environment detected. Using existing image sfsenorthamerica-fcto-spc.registry.snowflakecomputing.com/skhara/build_registry/snowml_repo/116da812e88f2751324c6a16eb00de3726ed06a3:latest to skip image build. To disable this feature, set 'force_image_build=True' in deployment options
# {'name': 'SKHARA.BUILD_REGISTRY.llama_predict',
#  'platform': <TargetPlatform.SNOWPARK_CONTAINER_SERVICES: 'SNOWPARK_CONTAINER_SERVICES'>,
#  'target_method': '__call__',
#  'signature': ModelSignature(
#                      inputs=[
#                          FeatureSpec(dtype=DataType.STRING, name='inputs')
#                      ],
#                      outputs=[
#                          FeatureSpec(dtype=DataType.STRING, name='outputs')
#                      ]
#                  ),
#  'options': {'compute_pool': 'SKHARA_COMPUTE_GPU3', 'num_gpus': 1},
#  'details': {'image_name': 'sfsenorthamerica-fcto-spc.registry.snowflakecomputing.com/skhara/build_registry/snowml_repo/116da812e88f2751324c6a16eb00de3726ed06a3:latest',
#   'service_spec': "spec:\n  container:\n  - env:\n      MODEL_ZIP_STAGE_PATH: SKHARA.BUILD_REGISTRY.snowml_model_0dfc6cb071db11ee9c1d0a72b796458c/0dfc6cb071db11ee9c1d0a72b796458c.zip\n      NUM_WORKERS: 1\n      SNOWML_USE_GPU: true\n      TARGET_METHOD: __call__\n      _CONCURRENT_REQUESTS_MAX: 1\n    image: sfsenorthamerica-fcto-spc.registry.snowflakecomputing.com/skhara/build_registry/snowml_repo/116da812e88f2751324c6a16eb00de3726ed06a3:latest\n    name: inference-server\n    readinessProbe:\n      path: /health\n      port: 5000\n    resources:\n      limits:\n        nvidia.com/gpu: 1\n      requests:\n        nvidia.com/gpu: 1\n    volumeMounts:\n    - mountPath: /local/user/vol1\n      name: vol1\n    - mountPath: SKHARA.BUILD_REGISTRY.snowml_model_0dfc6cb071db11ee9c1d0a72b796458c\n      name: stage\n  endpoint:\n  - name: predict\n    port: 5000\n  volume:\n  - name: vol1\n    source: local\n  - gid: 1000\n    name: stage\n    source: '@SKHARA.BUILD_REGISTRY.snowml_model_0dfc6cb071db11ee9c1d0a72b796458c'\n    uid: 1000\n",
#   'service_function_sql': "\n            CREATE OR REPLACE FUNCTION SKHARA.BUILD_REGISTRY.llama_predict(input OBJECT)\n                RETURNS OBJECT\n                SERVICE=SKHARA.BUILD_REGISTRY.service_0dfc6cb071db11ee9c1d0a72b796458c\n                ENDPOINT=predict\n                MAX_BATCH_ROWS = 1\n                AS '/predict'\n            "}}

# %% [markdown]
# # I/O Setup
#
# We will load a JSON file to a Snowflake Table. For prediction purposes, we have two options - use Snowpark DataFrame, use Local Pandas DataFrame.
# For sake of simplicity, we will use a Local Pandas Dataframe with only tow rows. If the dataset is big, it is advised to use Snowpark Dataframes.

# %% [markdown]
# ## Load Data

# %%
json_dataset = pd.read_json("frosty_dataset_generator/frosty_transcripts_all.jsonl", lines=True).convert_dtypes()
json_dataset.head()
# Out:
#                                           transcript   name       location  \
# 0  frosty: Hi there! This is Frosty. How can I he...   Alex        Houston
# 1  frosty: Hello, happy holiday! How can I help y...  Amber         London
# 2  frosty: Hi! I'm Frosty, how can I assist you t...  Bella  San Francisco
# 3  frosty: Hello! This is Frosty. How can I help ...   Luke      Melbourne
# 4  frosty: Hi, happy holidays! How can I assist y...   Owen        Toronto
#
#                                             toy_list
# 0  [Barbie Science Lab Playset, Pokémon 8-Inch Pl...
# 1            [Dog-E, 2023 Holiday Fox 12-Inch Plush]
# 2  [Transformers Rise of the Beasts Beast-Mode Bu...
# 3  [LeapFrog Magic Adventures Microscope, Marvel'...
# 4  [Star Wars LOLA animatronic droid, Fisher-Pric...

# %%
TABLE_NAME = "AK_BUILD_DATA"
session.write_pandas(json_dataset, table_name=TABLE_NAME, auto_create_table=True, overwrite=True)

# %% [markdown]
# ## Input: Prompt Engineering

# %%
session.sql('SELECT * from AK_BUILD_DATA LIMIT 5').to_pandas()
# Out:
#                                           transcript   name       location  \
# 0  frosty: Hi there! This is Frosty. How can I he...   Alex        Houston
# 1  frosty: Hello, happy holiday! How can I help y...  Amber         London
# 2  frosty: Hi! I'm Frosty, how can I assist you t...  Bella  San Francisco
# 3  frosty: Hello! This is Frosty. How can I help ...   Luke      Melbourne
# 4  frosty: Hi, happy holidays! How can I assist y...   Owen        Toronto
#
#                                             toy_list
# 0  [\n  "Barbie Science Lab Playset",\n  "Pokémon...
# 1  [\n  "Dog-E",\n  "2023 Holiday Fox 12-Inch Plu...
# 2  [\n  "Transformers Rise of the Beasts Beast-Mo...
# 3  [\n  "LeapFrog Magic Adventures Microscope",\n...
# 4  [\n  "Star Wars LOLA animatronic droid",\n  "F...

# %%
sdf_input = session.table('AK_BUILD_DATA')
df_local = sdf_input.limit(20).to_pandas()
df_local.head()
# Out:
#                                           transcript   name       location  \
# 0  frosty: Hi there! This is Frosty. How can I he...   Alex        Houston
# 1  frosty: Hello, happy holiday! How can I help y...  Amber         London
# 2  frosty: Hi! I'm Frosty, how can I assist you t...  Bella  San Francisco
# 3  frosty: Hello! This is Frosty. How can I help ...   Luke      Melbourne
# 4  frosty: Hi, happy holidays! How can I assist y...   Owen        Toronto
#
#                                             toy_list
# 0  [\n  "Barbie Science Lab Playset",\n  "Pokémon...
# 1  [\n  "Dog-E",\n  "2023 Holiday Fox 12-Inch Plu...
# 2  [\n  "Transformers Rise of the Beasts Beast-Mo...
# 3  [\n  "LeapFrog Magic Adventures Microscope",\n...
# 4  [\n  "Star Wars LOLA animatronic droid",\n  "F...

# %%
def add_prompt(transcript):
    prompt = f'''[INST] <PROMPT>
    Your output will be parsed by a computer program as a JSON object. Please respond ONLY with valid json that conforms to this JSON schema:
    {{
      "name": {{
        "type": "string",
        "description": "The name of the person calling"
      }},
      "location": {{
        "type": "string",
        "description": "The name of the location where the person is calling from."
      }},
      "toy_list": {{
        "type": "array",
        "description": "The list of toys requested by the person calling."
      }},
      "required": ["name", "location", "toy_list"]
    }}


    Example 1:
    Input: "{df_local['transcript'].iloc[0]}"
    Output: {{"name": {df_local['name'].iloc[0]}, "location": {df_local['location'].iloc[0]}, "toy_list": {df_local['toy_list'].iloc[0]}}}

    Example 2:
    Input: "{df_local['transcript'].iloc[1]}"
    Output: {{"name": {df_local['name'].iloc[1]}, "location": {df_local['location'].iloc[1]}, "toy_list": {df_local['toy_list'].iloc[1]}}}
    </PROMPT>

    Actual Input: {transcript}
    [/INST]
    '''
    return prompt

# %%
df_local['inputs'] = df_local['transcript'].apply(add_prompt)
print(df_local['inputs'].iloc[3])
# Out:
# [INST] <PROMPT>
#     Your output will be parsed by a computer program as a JSON object. Please respond ONLY with valid json that conforms to this JSON schema:
#     {
#       "name": {
#         "type": "string",
#         "description": "The name of the person calling"
#       },
#       "location": {
#         "type": "string",
#         "description": "The name of the location where the person is calling from."
#       },
#       "toy_list": {
#         "type": "array",
#         "description": "The list of toys requested by the person calling."
#       },
#       "required": ["name", "location", "toy_list"]
#     }
#
#
#     Example 1:
#     Input: "frosty: Hi there! This is Frosty. How can I help you today?
# caller: Hi Frosty, I want to make my holiday wish.
# frosty: Of course! May I know your name, please?
# caller: I'm Alex.
# frosty: Hi Alex! Where are you calling from?
# caller: From Houston.
# frosty: Wonderful! Now, what's your holiday wish?
# caller: I want the barbie science doll set and pokemon plushie.
# frosty: Awesome choices, Alex! Your list has been added. Thanks for calling and have a jolly Holiday!"
#     Output: {"name": Alex, "location": Houston, "toy_list": [
#   "Barbie Science Lab Playset",
#   "Pokémon 8-Inch Plush First Partner Three-Pack"
# ]}
#
#     Example 2:
#     Input: "frosty: Hello, happy holiday! How can I help you today?
# caller: I'm Amber. I want to give my wish list.
# frosty: Of course, Amber! What's on your wish list?
# caller: robot dog and the fox plushie.
# frosty: Brilliant choices, Amber! And where are you calling from?
# caller: From London.
# frosty: Alright, Amber from London. Your list has been recorded. Have a fantastic holiday!"
#     Output: {"name": Amber, "location": London, "toy_list": [
#   "Dog-E",
#   "2023 Holiday Fox 12-Inch Plush"
# ]}
#     </PROMPT>
#
#     Actual Input: frosty: Hello! This is Frosty. How can I help you?
# caller: Hi, I'm Luke.
# frosty: Hi Luke! Where are you calling from?
# caller: I'm calling from Melbourne.
# frosty: Great! What would you like to wish for, Luke?
# caller: I wish for magic microscope and spiderman playset.
# frosty: Good choices, Luke! Your wish list has been recorded. Happy Holidays!
#     [/INST]

# %% [markdown]
# ## Output: Processing
# Ensure that processing code conforms to the JSON Structure provided during Prompt Engineering.

# %%
import json
def format_output(output_string):
    try:
        outer_list = json.loads(output_string)
        generated_text_str = outer_list[0]['generated_text']
        
        end_pos = generated_text_str.rfind('}')
        if end_pos == -1:
            raise ValueError("No closing brace found in generated_text")
        json_str = generated_text_str[:end_pos + 1]
        
        generated_text_dict = json.loads(json_str)
        return generated_text_dict
    except:
        return 'Could not parse output'

# %% [markdown]
# # Get Predictions

# %% [markdown]
# ## Get Deployed Model

# %%
registry_name = 'SKHARA'
schema_name = 'BUILD_REGISTRY'

registry = model_registry.ModelRegistry(session= session,
                                        database_name= registry_name,
                                        schema_name= schema_name)

# %%
model_list = registry.list_models()
model_list.to_pandas()
# Out:
#   CREATION_CONTEXT   CREATION_ENVIRONMENT_SPEC    CREATION_ROLE  \
# 0             None  {\n  "python": "3.9.17"\n}  "SPC_USER_ROLE"
# 1             None  {\n  "python": "3.9.17"\n}  "SPC_USER_ROLE"
# 2             None  {\n  "python": "3.9.17"\n}  "SPC_USER_ROLE"
# 3             None  {\n  "python": "3.9.17"\n}  "SPC_USER_ROLE"
# 4             None  {\n  "python": "3.9.17"\n}  "SPC_USER_ROLE"
#
#                      CREATION_TIME                                ID  \
# 0 2023-10-18 11:19:26.257000-07:00  d90f1c246de211eeae210a72b796458c
# 1 2023-10-18 11:20:31.620000-07:00  0168781e6de311eeae210a72b796458c
# 2 2023-10-23 08:23:21.668000-07:00  1454b4e671b811eeb25b0a72b796458c
# 3 2023-10-23 11:06:19.746000-07:00  d870c6ec71ce11ee9c1d0a72b796458c
# 4 2023-10-23 12:33:41.971000-07:00  0dfc6cb071db11ee9c1d0a72b796458c
#
#   INPUT_SPEC                  NAME OUTPUT_SPEC RUNTIME_ENVIRONMENT_SPEC  \
# 0       None  LLAMA2_MODEL_7b_CHAT        None                     None
# 1       None  LLAMA2_MODEL_7b_CHAT        None                     None
# 2       None  LLAMA2_MODEL_7b_CHAT        None                     None
# 3       None  LLAMA2_MODEL_7b_CHAT        None                     None
# 4       None  LLAMA2_MODEL_7b_CHAT        None                     None
#
#                    TYPE                                                URI  \
# 0  huggingface_pipeline  sfc://SKHARA.BUILD_REGISTRY.SNOWML_MODEL_D90F1...
# 1  huggingface_pipeline  sfc://SKHARA.BUILD_REGISTRY.SNOWML_MODEL_01687...
# 2  huggingface_pipeline  sfc://SKHARA.BUILD_REGISTRY.SNOWML_MODEL_1454B...
# 3  huggingface_pipeline  sfc://SKHARA.BUILD_REGISTRY.SNOWML_MODEL_D870C...
# 4  huggingface_pipeline  sfc://SKHARA.BUILD_REGISTRY.SNOWML_MODEL_0DFC6...
#
#   VERSION ARTIFACT_IDS DESCRIPTION METRICS  TAGS  \
# 0       3           []        None    None  None
# 1       4           []        None    None  None
# 2       5           []        None    None  None
# 3       6           []        None    None  None
# 4       7           []        None    None  None
#
#             REGISTRATION_TIMESTAMP
# 0 2023-10-18 11:19:27.494000-07:00
# 1 2023-10-18 11:20:33.306000-07:00
# 2 2023-10-23 08:23:22.988000-07:00
# 3 2023-10-23 11:06:21.405000-07:00
# 4 2023-10-23 12:33:43.307000-07:00

# %%
model_list = registry.list_deployments(model_name = model_name, model_version='7')
model_list.to_pandas()
# Out:
#              MODEL_NAME MODEL_VERSION DEPLOYMENT_NAME  \
# 0  LLAMA2_MODEL_7b_CHAT             7   llama_predict
#
#                      CREATION_TIME TARGET_METHOD              TARGET_PLATFORM  \
# 0 2023-10-23 12:35:19.101000-07:00      __call__  SNOWPARK_CONTAINER_SERVICES
#
#                                            SIGNATURE  \
# 0  {\n  "inputs": [\n    {\n      "name": "inputs...
#
#                                              OPTIONS  \
# 0  {\n  "compute_pool": "SKHARA_COMPUTE_GPU3",\n ...
#
#                                           STAGE_PATH             ROLE
# 0  @SKHARA.BUILD_REGISTRY._SYSTEM_REGISTRY_DEPLOY...  "SPC_USER_ROLE"

# %%
model_name = 'LLAMA2_MODEL_7b_CHAT'
model = model_registry.ModelReference(registry=registry, model_name=model_name, model_version='7')

# %% [markdown]
# ## Predict & See Outputs

# %%
res = model.predict(
    deployment_name= 'llama_predict',
    data= df_local[['inputs']]
)

# %%
for i in range(len(df_local)):
    print(f'\n\n **** Transcript # {i} ****')
    print(df_local['transcript'].iloc[i])
    print('\n')
    print(format_output(res['outputs'].iloc[i]))
# Out:
#  **** Transcript # 0 ****
# frosty: Hi there! This is Frosty. How can I help you today?
# caller: Hi Frosty, I want to make my holiday wish.
# frosty: Of course! May I know your name, please?
# caller: I'm Alex.
# frosty: Hi Alex! Where are you calling from?
# caller: From Houston.
# frosty: Wonderful! Now, what's your holiday wish?
# caller: I want the barbie science doll set and pokemon plushie.
# frosty: Awesome choices, Alex! Your list has been added. Thanks for calling and have a jolly Holiday!
#
#
# Could not parse output
#
#
#  **** Transcript # 1 ****
# frosty: Hello, happy holiday! How can I help you today?
# caller: I'm Amber. I want to give my wish list.
# frosty: Of course, Amber! What's on your wish list?
# caller: robot dog and the fox plushie.
# frosty: Brilliant choices, Amber! And where are you calling from?
# caller: From London.
# frosty: Alright, Amber from London. Your list has been recorded. Have a fantastic holiday!
#
#
# Could not parse output
#
#
#  **** Transcript # 2 ****
# frosty: Hi! I'm Frosty, how can I assist you today?
# caller: Hi, I'm Bella from San Francisco.
# frosty: Wonderful, Bella! How can I assist you today?
# caller: I wish for trasformers bumblebee and the new barbie dreamhouse.
# frosty: Those are fantastic wishes, Bella! I've added these to your list. Enjoy your holidays!
#
#
# Could not parse output
#
#
#  **** Transcript # 3 ****
# frosty: Hello! This is Frosty. How can I help you?
# caller: Hi, I'm Luke.
# frosty: Hi Luke! Where are you calling from?
# caller: I'm calling from Melbourne.
# frosty: Great! What would you like to wish for, Luke?
# caller: I wish for magic microscope and spiderman playset.
# frosty: Good choices, Luke! Your wish list has been recorded. Happy Holidays!
#
#
# Could not parse output
#
#
#  **** Transcript # 4 ****
# frosty: Hi, happy holidays! How can I assist you?
# caller: Hi, I'm Owen from Toronto.
# frosty: Hello, Owen! What are your holiday wishes?
# caller: I wish for lola droid and mickey playset.
# frosty: Brilliant! Your wishes have been noted, Owen. Have a fantastic holiday!
#
#
# {'name': 'Owen', 'location': 'Toronto', 'toy_list': ['Lola Droid', 'Mickey Playset']}
#
#
#  **** Transcript # 5 ****
# frosty: Hi there! Frosty here. How may I assist you today?
# caller: Hi, I'm Lily. I want to give you my holiday wishes.
# frosty: Hello, Lily! I'm eager to hear your wishes. What are they?
# caller: My wishes are furby and bluey car.
# frosty: Sure thing, Lily! Where are you calling from?
# caller: From Vancouver.
# frosty: Thanks, Lily from Vancouver. Your wishes have been added. Enjoy your holidays!
#
#
# Could not parse output
#
#
#  **** Transcript # 6 ****
# frosty: Hello! How may I assist you today?
# caller: Hi, I'm Jake from Dublin.
# frosty: Hello, Jake! What's your holiday wish?
# caller: My holiday wish is gabby dollhouse.
# frosty: That's a fun wish, Jake! Your wish has been added. Have a joyful holiday!
#
#
# {'name': 'Jake', 'location': 'Dublin', 'toy_list': ['Gabby Dollhouse']}
#
#
#  **** Transcript # 7 ****
# frosty: Hello, I'm Frosty! How can I help you?
# caller: Hi Frosty, I'm Grace.
# frosty: Hi Grace! Where are you calling from?
# caller: From Auckland.
# frosty: Wonderful, Grace! What is your holiday wish?
# caller: bluey playhouse is my wish.
# frosty: Excellent! Your wish has been added, Grace. Have a wonderful holiday!
#
#
# Could not parse output
#
#
#  **** Transcript # 8 ****
# frosty: Hi! Hoping you're having a joyful day. How can I help you?
# caller: Hi, I'm Adam from Sydney.
# frosty: Hello Adam! What would you like to wish for this holiday?
# caller: My wish is lego olivia's space set.
# frosty: That's a wonderful wish, Adam! Your wish has been sent. Have a fantastic holiday!
#
#
# Could not parse output
#
#
#  **** Transcript # 9 ****
# frosty: Hello there! How may I assist you?
# caller: Hi, I'm Ava.
# frosty: Hi Ava! Where are you calling from?
# caller: I'm calling from Manchester.
# frosty: Great Ava! What's your holiday wish?
# caller: fingerlings monkey, please.
# frosty: Awesome choice, Ava! Your wish list has been recorded. Have a joyous holiday!
#
#
# {'name': 'Ava', 'location': 'Manchester', 'toy_list': ['Fingerlings Monkey']}
#
#
#  **** Transcript # 10 ****
# frosty: Hello there, lovely child! What's your name?
# caller: I'm Billy.
# frosty: Nice to meet you, Billy! Where are you from?
# caller: Sydney.
# frosty: That's a great city, Billy from Sydney! What can Frosty gift you this holiday?
# caller: I want the furby and the bluey car.
#
#
# Could not parse output
#
#
#  **** Transcript # 11 ****
# frosty: Hi there, little one! May I know your name?
# caller: Hi Frosty, I'm Emma and I live in Houston.
# frosty: Lovely to hear from you, Emma from Houston! Have you thought about your holiday wish list?
# caller: Yes, I want the spiderman playset.
#
#
# Could not parse output
#
#
#  **** Transcript # 12 ****
# frosty: Ho Ho Ho! What's your name, dear friend?
# caller: Hi, I'm Oliver.
# frosty: Hello, Oliver! Where are you calling from?
# caller: I'm from Auckland.
# frosty: A wonderful place, Oliver! What would make this holiday merrier for you?
# caller: I wish for the lola droid and the ninja turtles delivery van.
#
#
# Could not parse output
#
#
#  **** Transcript # 13 ****
# frosty: Hello my little friend, what's your name?
# caller: I'm Leah from Toronto.
# frosty: Hello there Leah from Toronto! What would make your holidays joyful?
# caller: I hope to get the baby bee doll and the playfoam letters.
#
#
# Could not parse output
#
#
#  **** Transcript # 14 ****
# frosty: Greetings! Can I have your lovely name?
# caller: My name is Michael. I'm from London.
# frosty: Nice to meet you, Michael from London! What do you want for this holiday season?
# caller: I want the jurassic world dinosaur.
#
#
# Could not parse output
#
#
#  **** Transcript # 15 ****
# frosty: Merry Greetings! What's your name, little one?
# caller: I am Amy.
# frosty: Lovely to have you here, Amy! Where is home for you?
# caller: From Melbourne.
# frosty: Oh, beautiful place, Amy! What's on your holiday wish list?
# caller: I want the lego olivia's space set and the mickey playset.
#
#
# Could not parse output
#
#
#  **** Transcript # 16 ****
# frosty: Hi there! Who do I have the pleasure of talking to?
# caller: My name is Jake, and I am from Birmingham.
# frosty: Nice to meet you, Jake from Birmingham! What are we hoping for this holiday?
# caller: I hope for the trasformers bumblebee.
#
#
# Could not parse output
#
#
#  **** Transcript # 17 ****
# frosty: Ho Ho Ho! What's your name, dear friend?
# caller: I'm Chloe.
# frosty: Hello Chloe, where are you calling from?
# caller: From Christchurch.
# frosty: A wonderful place, Chloe! What would make your holidays brighter?
# caller: I wish for the gabby dollhouse and the pony’s hair salon.
#
#
# Could not parse output
#
#
#  **** Transcript # 18 ****
# frosty: Season's greetings! What's your name?
# caller: I’m Mia and I want the barbie science doll set.
# frosty: That's a great choice, Mia! But can I know where you are calling from?
# caller: Oh, I am from Sydney.
#
#
# Could not parse output
#
#
#  **** Transcript # 19 ****
# frosty: Hello, dear child! I'm Frosty, may I have your name please?
# caller: Hi Frosty, I'm Ethan and I am from Auckland.
# frosty: That's great to know, Ethan from Auckland! What would you like to receive this holiday?
# caller: I would like to have the snap circuit set.
#
#
# {'name': 'Ethan', 'location': 'Auckland', 'toy_list': ['Snap Circuit Set']}
